# %%
import requests
from bs4 import BeautifulSoup  
import pandas as pd
import re

# %% [markdown]
# ###### Read the File that was saved previously from the Induction Data Frame

# %%
artist_df = pd.read_csv('induction.csv')

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   artist  140 non-null    object
#  1   year    140 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.3+ KB

# %% [markdown]
# ##### Review the Data Frame

# %%
artist_df
# Out:
#             artist  year
# 0        Roy Acuff  1962
# 1          Alabama  2005
# 2    Bill Anderson  2001
# 3      Eddy Arnold  1966
# 4      Chet Atkins  1973
# ..             ...   ...
# 135  Hank Williams  1961
# 136      Bob Wills  1968
# 137    Mac Wiseman  2014
# 138  Tammy Wynette  1998
# 139    Faron Young  2000
#
# [140 rows x 2 columns]

# %%
# Create a third column after cleaning the data to be utilized to go different artist pages by url
# First, change name to lower case, replace '\' '.' '&' '"'' to nothing

artist_df['ar_url'] = artist_df.artist.str.lower()
artist_df['ar_url'] = artist_df.ar_url.replace('\"',"")
artist_df['ar_url'] = artist_df.ar_url.replace('&"',"")
artist_df['ar-url'] = artist_df.ar_url.str.replace(".","").str.replace(" ","-")

# This clean up was not cleaning "  in the strings and therefore chose to try a different method

# %%
artist_df.tail(60)
# Out:
#                        artist  year                    ar_url  \
# 80                 Ken Nelson  2001                ken nelson
# 81              Willie Nelson  1993             willie nelson
# 82             Oak Ridge Boys  2015            oak ridge boys
# 83                 Buck Owens  1996                buck owens
# 84               Dolly Parton  1999              dolly parton
# 85               Minnie Pearl  1975              minnie pearl
# 86                 Ralph Peer  1984                ralph peer
# 87               Sam Phillips  2001              sam phillips
# 88                Webb Pierce  2001               webb pierce
# 89              Elvis Presley  1998             elvis presley
# 90            Frances Preston  1992           frances preston
# 91                  Ray Price  1996                 ray price
# 92              Charley Pride  2000             charley pride
# 93                ​Jerry Reed  2017               ​jerry reed
# ...

# %%
for artist in the artist_df:
    re

# %%
website_url = 'https://countrymusichalloffame.org/artist/roy-acuff/'
response = requests.get(website_url)

response.status_code
# Out:
# 200

# %%
print(type(response))
# Out:
# <class 'requests.models.Response'>

# %% [markdown]
# #### WEB SCRAPING TAGS
# - Fact 1: HTML consists of Tags - < strong > dfdfdfd </strong >
# - Fact 2: Tags have attributes - < span class="short-desc" >
# - Fact 3: Tags can be Nested
# - read https://www.dataschool.io/python-web-scraping-of-president-trumps-lies/

# %%
soup = BeautifulSoup(response.content, 'lxml')
print(soup.title)
# Out:
# <title>Roy Acuff | Artist Bio | Country Music Hall of Fame</title>

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
# })(window,document,'script','dataLayer','GTM-TVMMMDC');</script>
# <!-- End Google Tag Manager -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# ...

# %%
# identify a tag that might be helpful for finding the names of all inductees

profile1 = soup.find_all('div', attrs = {'class': 'fl-rich-text detail-wrapper'})

# %%
len(profile1)
# shows one record
# Out:
# 1

# %%
profile1
# Out:
# [<div class="fl-rich-text detail-wrapper">
#  <p>INDUCTED :  1962</p>
#  <h1>Roy Acuff</h1>
#  <p></p><p>Roy Claxton Acuff emerged as a star during the early 1940s.</p>
#  <p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: September 15, 1903 - Death: November 23, 1992 <br/> Birthplace: Maynardville, Tennessee </p>
#  </div>]

# %%
life_span = [] 
#for element in soup.find_all('div', attrs = {'class': 'fl-rich-text detail-wrapper'}):
profile =soup.find('p', attrs = {'style':'margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;'})

details =profile.text

# %%
profile
# Out:
# <p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: September 15, 1903 - Death: November 23, 1992 <br/> Birthplace: Maynardville, Tennessee </p>

# %%
details
# Out:
# 'Birth: September 15, 1903 - Death: November 23, 1992  Birthplace: Maynardville, Tennessee '

# %%
#regex = (r'Birth:\s+(.*)')
#regex = (r'Birth:[A-Z][a-z] [0-2]*')
birth1=re.findall("Birth: (\w+\s\d+, \d+)", details)
death1=re.findall('Death: (\w+\s\d+, \d+)', details)
b_place=re.findall('Birthplace: (\w+, \w+)', details)

#re.findall(regex,details) 
print(birth1)
print(death1)
print(b_place)
# Out:
# ['September 15, 1903']
# ['November 23, 1992']
# ['Maynardville, Tennessee']

# %%
birth = []
death = []
birthplace = []

x = details.split(" - ",1)
y = details.split("  ",1)

# %%
x
# Out:
# ['Birth: September 15, 1903',
#  'Death: November 23, 1992  Birthplace: Maynardville, Tennessee ']

# %%
x[-1]
# Out:
# 'Death: November 23, 1992  Birthplace: Maynardville, Tennessee '

# %%
z = x[1].split("  ",1)
z
# Out:
# ['Death: November 23, 1992', 'Birthplace: Maynardville, Tennessee ']
